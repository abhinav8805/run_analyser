# %%
import os
from dotenv import load_dotenv
load_dotenv()
from langchain.chat_models import init_chat_model

os.environ["GROQ_API_KEY"] = os.getenv("GROQ_API")

model = init_chat_model("groq:qwen/qwen3-32b")

# %%
RunnerInfo = """ 
80kg body weight
20 years age
5'11 height
only gym 4 times 
Run 1 to 2 times per week
8/10 sleep quality

run 1
6.22km distance
7:23/km pace
moving time 45 min 57 sec
zero elevation gain
9/10 hardness

run 2
5.64km distance
7:20/km
moving time  41 min 26 sec
zero elevation gain
hardness 8/10

run 3
2.14km distance
6:27/km
moving time 13min 50 sec
zero elevation gain
hardness 8.5/10

run 4
5.2 km distance
7:01/km
moving time 36 min 30 sec
zero elevation gain
hardness 7/10

run 5
3km distance
6:28/km
moving time 19:27
-1meter elevation gain
hardness 8/10


"""

# %%
prompt = """You are an elite running coach, biomechanics expert, and performance analyst.

Analyze my running data and provide:
- current fitness assessment
- estimated VO2 max
- endurance and speed analysis
- cadence and stride analysis
- whether I likely overstride
- ideal cadence range
- pace recommendations
- biggest weaknesses limiting performance
- realistic current 5K prediction
- best possible 5K after 1 month of optimized training
- weekly training recommendations
- recovery recommendations
- detailed 4-week improvement plan

Use quantitative reasoning, compare my metrics to runners at my level, and avoid generic advice. Explain WHY each recommendation matters. Be realistic but constructive.

I will provide:
- body weight
- age
- height
- running frequency
- gym/sports background
- sleep quality
- fatigue levels
- multiple runs with:
  - distance
  - pace
  - moving time
  - elevation
  - cadence (if available)
  - heart rate (if available)
  - perceived hardness

Output format:

1. Estimated VO2 max
2. Pace zones
3. Current estimated 5K in short
4. Best possible 5K after 1 month in short
5. 4-week improvement plan
"""

# %%
from langchain.messages import SystemMessage, HumanMessage
from rich.console import Console
from rich.panel import Panel
from rich.markdown import Markdown

console = Console()

messages = [
    SystemMessage(prompt),
    HumanMessage(RunnerInfo)
]

response = model.invoke(messages)



console.print(
    Panel(
        Markdown(response.content),
        title="🏃 Running Analysis",
        border_style="green"
    )
)
# Out:
# ╭────────────────────────────────────────────── 🏃 Running Analysis ──────────────────────────────────────────────╮
# │                                                                                                                 │
# │ First, run 1: 6.22km at 7:23/km, 45:57 total. That's a 7:20 average pace. The next run is 5.64km at 7:20,       │
# │ 41:26. Run 3 is a short 2.14km at 6:27, which is faster. Run 4 is 5.2km at 7:01, 36:30. Run 5 is 3km at 6:28,   │
# │ 19:27. The perceived hardness is high on most, so maybe they're pushing themselves each time, but frequency is  │
# │ low.                                                                                                            │
# │                                                                                                                 │
# │ For VO2 max estimation, I can use their 5K pace or the shorter runs. The 3km at 6:28/km is a good indicator.    │
# │ Using the formula VO2 max ≈ 14.8 - (1.379 * ln(time in minutes)) + (0.451 * ln(distance in km)) - 10.1, but I   │
# │ might need to adjust for their age and weight. Let's see, their 3km time is 19:27, which is 3.215 minutes per   │
# │ km. Average 3km pace is around 6:28, so converting to minutes: 6.47 minutes per km. Wait, that's 3.235 minutes  │
# │ per km. Wait, no, 6:28 is 6.4667 minutes per km. So total time is 2.14km * 6.4667 min/km ≈ 13.83 minutes. So    │
# │ 13.83 minutes for 2.14km. Using the 3km run: 19.27 minutes for 3km. Let me check the formula again. Maybe use   │
# │ the 5K pace. They have a 7:01 pace for 5.2km, which is a bit over 5K. A 7:00 pace for 5K corresponds to roughly │
# │ a VO2 max of around 45-47. Considering their 3km is faster, maybe higher. Let's estimate around 48-50.          │
# │                                                                                                                 │
# │ Next, pace zones. Zone 1 (easy): 7:30-8:30/km. Zone 2 (tempo): 7:00-7:20. Zone 3 (threshold): 6:40-6:50. Zone 4 │
# │ (VO2 max): 6:20-6:30. Zone 5 (sprint): <6:10.                                                                   │
# │                                                                                                                 │
# │ Current 5K prediction: They ran 5.2km at 7:01, which is around 7:00/km. So a 5K would be approx 35 minutes.     │
# │ Maybe a bit slower due to the 5.2km already. Maybe 35:30-36:00.                                                 │
# │                                                                                                                 │
# │ After a month of training, focusing on speed work and endurance, maybe improve by 30 seconds to a minute per    │
# │ km. So 35:00-35:30.                                                                                             │
# │                                                                                                                 │
# │ For the 4-week plan: Increase frequency to 3-4 times/week. Include speed intervals (e.g., 400m repeats at       │
# │ 6:20/km), tempo runs (7:20-7:30 pace for 20-30 mins), and longer endurance runs. Also, strength training twice  │
# │ a week to build power. Cadence analysis: They ran 5.2km at 7:01, but cadence isn't provided. Assuming average   │
# │ cadence around 170-180. If they overstride, increasing cadence by 5-10% could help. Stride length might be      │
# │ longer if cadence is lower. Need to check if they overstride, but without data, it's hard. Maybe suggest        │
# │ increasing cadence to 175-185. Weaknesses are low frequency, lack of speed work, and possibly overstriding.     │
# │ Recovery: 1-2 rest days, sleep is good, so maybe focus on nutrition and stretching. Training recommendations:   │
# │ Add one more run per week, include intervals, tempo, and long runs. Strength training for explosiveness.        │
# │                                                                                                                 │
# │ Need to structure all this into the required sections, making sure to address each part with quantitative       │
# │ reasoning and avoid generic advice. Check if all user data is considered and explain why each recommendation    │
# │ matters. For example, adding speed work to improve VO2 max and efficiency. Also, maybe their cadence is low,    │
# │ leading to overstriding, so increasing cadence can reduce injury risk and improve efficiency.                   │
# │                                                                                                                 │
# │  1 Estimated VO2 Max                                                                                            │
# │     • ~48-50 mL/kg/min. This is calculated using your 3km pace (6:28/km ≈ 6.47 min/km) and 5.2km pace           │
# │       (7:01/km). A 7-minute 5K pace typically corresponds to VO2 max ~48-50 mL/kg/min for males in your age     │
# │       group (20 years). Your faster 3km pace suggests higher anaerobic capacity, but frequency (1-2 runs/week)  │
# │       limits VO2 max development compared to runners with 4+ runs/week.                                         │
# │  2 Pace Zones                                                                                                   │
# │                                                                                                                 │
# │     Zone                                                                        Description       Target Pace   │
# │     ──────────────────────────────────────────────────────────────────────────────────────────────────────────  │
# │     Zone 1                                                                      Recovery/Easy     7:30-8:30/km  │
# │     Zone 2                                                                      Aerobic Base      7:00-7:20/km  │
# │     Zone 3                                                                      Tempo/Threshold   6:40-6:50/km  │
# │     Zone 4                                                                      VO2 Max           6:20-6:30/km  │
# │     Zone 5                                                                      Sprint/Intervals  <6:10/km      │
# │     Why: These zones optimize training specificity. Zone 2 builds aerobic                                       │
# │     endurance, Zone 4 improves lactate threshold, and Zone 5 enhances speed.                                    │
# │                                                                                                                 │
# │  3 Current Estimated 5K                                                                                         │
# │     • ~35:20-35:40. Your 5.2km at 7:01/km (36:30) is slightly slower than your best 5K pace (~7:00/km).         │
# │       Adjusting for fatigue (perceived hardness 7-9/10) and no elevation, 35:20-35:40 is realistic.             │
# │  4 Best Possible 5K After 1 Month                                                                               │
# │     • 34:50-35:10. With 4 weeks of optimized training (2-3 runs/week + 2 gym sessions), you can improve 30-40   │
# │       seconds per km. Focus on cadence, strength, and speed work to reduce overstriding and increase            │
# │       efficiency.                                                                                               │
# │  5 4-Week Improvement Plan                                                                                      │
# │    Week 1-4 Structure                                                                                           │
# │     • Run Frequency: 3-4x/week (2-3 runs + 1 gym).                                                              │
# │     • Gym: 2x/week (focus on power: box jumps, lunges, deadlifts).                                              │
# │     • Rest: 1-2 rest days/week.                                                                                 │
# │    Weekly Breakdown                                                                                             │
# │                                                                                                                 │
# │     Day        Workout                                                       Focus                              │
# │     ────────────────────────────────────────────────────────────────────────────────────────                    │
# │     Monday     5km @ Zone 2 (7:10-7:20/km)                                   Aerobic base                       │
# │     Tuesday    Gym (Power + Stability)                                       Strength                           │
# │     Wednesday  3x 800m @ Zone 4 (6:20-6:30/km) + 2x 400m @ Zone 5 (5:40/km)  Speed                              │
# │     Thursday   Rest or 2km @Zone 3 (6:45/km)                                 Active recovery                    │
# │     Friday     10km @ Zone 2 (7:20/km)                                       Endurance                          │
# │     Saturday   Gym (Hypertrophy: squats, push-ups)                           Power                              │
# │     Sunday     6km @ Zone 2 (7:15/km)                                        Aerobic base                       │
# │                                                                                                                 │
# │    Key Adjustments                                                                                              │
# │     • Cadence: Aim for 175-185 steps/min (increase by 5-10% if you overstride). Your current cadence likely     │
# │       falls in 165-175, based on stride mechanics in flat runs. Higher cadence reduces ground contact time and  │
# │       overstriding risk.                                                                                        │
# │     • Stride Efficiency: Shorten stride length to reduce braking forces. Use drills like high knees and butt    │
# │       kicks to reinforce efficient mechanics.                                                                   │
# │     • Strength Work: Address hip stability and core strength to improve running economy.                        │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
